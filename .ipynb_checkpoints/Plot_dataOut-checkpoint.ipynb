# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate

from matplotlib import animation
from JSAnimation import IPython_display

# %matplotlib inline

# %%
filename='data.out'
with open(filename,'r') as myfile:
    nnod = int(myfile.readline())
    
data = np.genfromtxt(filename,skip_header=1,skip_footer=1)

# %%
len(data.T[0])/nnod
# Out:
# 4973.0

# %%
N = 1

x = data.T[0][(N-1)*nnod:(N)*nnod]
y = data.T[1][(N-1)*nnod:(N)*nnod]
z = data.T[2][(N-1)*nnod:(N)*nnod]

xi, yi = np.linspace(x.min(), x.max(), 100), np.linspace(y.min(), y.max(), 100)
xi, yi = np.meshgrid(xi, yi)

rbf = scipy.interpolate.Rbf(x, y, z, function='linear')
zi = rbf(xi, yi)

plt.imshow(zi, vmin=z.min(), vmax=z.max(), origin='lower',
           extent=[x.min(), x.max(), y.min(), y.max()])
plt.scatter(x, y, c=z)


plt.colorbar()
plt.show()

# %%
fig = plt.figure(figsize=(7,7))
ax = plt.axes()
#line, = ax.plot([], [], lw=2)

# choose a different color for each trajectory
#colors = plt.cm.jet(np.linspace(0, 1, numPar))

## set up lines and points
#lines = sum([ax.plot([], [], '-', c=c, alpha=0.5)
#             for c in colors], [])
#pts = sum([ax.plot([], [], 'o', c=c)
#           for c in colors], [])

#def init():
#    for line, pt in zip(lines, pts):
#        line.set_data([], [])
#        pt.set_data([], [])
#        
#    return lines + pts

def animate(i):
    for j in np.arange(len(data.T[0])/nnod):
        x = data.T[0][(j-1)*nnod:(j)*nnod]
        y = data.T[1][(j-1)*nnod:(j)*nnod]
        z = data.T[2][(j-1)*nnod:(j)*nnod]
        
        xi, yi = np.linspace(x.min(), x.max(), 20), np.linspace(y.min(), y.max(), 20)
        xi, yi = np.meshgrid(xi, yi)
        
        
        
        
        line.set_data(x, y)
        pt.set_data(x[-1:],y[-1:])
        
    return lines + pts
#    for j in np.arange(4):
#        pt.set_data(r[j*2][i], r[j*2+1][i])
#    mass1.set_data(r[0][i], r[1][i])
#    mass2.set_data(r[2][i], r[3][i])
#    mass3.set_data(r[4][i], r[5][i])
#    mass4.set_data(r[6][i], r[7][i])
#    return mass1, mass2, mass3, mass4,
#    x = np.linspace(0, 10, 1000)
#    y = np.cos(i * 0.02 * np.pi) * np.sin(x - i * 0.02 * np.pi)
#    line.set_data(x, y)
#    return line,
#    return mass,

animation.FuncAnimation(fig, animate, #init_func=init,
                        frames=NSteps, interval=1)

# %%
len(np.unique(x))
# Out:
# 21
